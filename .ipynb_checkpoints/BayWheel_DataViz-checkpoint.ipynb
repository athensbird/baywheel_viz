# %% [markdown]
# # BayWheel Bike Data Visualziation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import math
import datetime
# %matplotlib inline

# %%
# import all the csv files
files = ['201801-fordgobike-tripdata.csv', '201802-fordgobike-tripdata.csv',
        '201803-fordgobike-tripdata.csv','201804-fordgobike-tripdata.csv',
        '201805-fordgobike-tripdata.csv','201806-fordgobike-tripdata.csv',
        '201807-fordgobike-tripdata.csv','201808-fordgobike-tripdata.csv',
        '201809-fordgobike-tripdata.csv','201810-fordgobike-tripdata.csv',
        '201811-fordgobike-tripdata.csv','201812-fordgobike-tripdata.csv']

# %%
# loop through the file directory, append each file to the dataframe then reset the index 
df = pd.DataFrame()
for file in files:
    if df.empty:
        df = pd.read_csv(file)
    else:
        new_df = pd.read_csv(file)
        df = pd.concat([df, new_df], ignore_index=True)
df.reset_index()
# Out:
#            index  duration_sec                start_time  \
# 0              0         75284  2018-01-31 22:52:35.2390
# 1              1         85422  2018-01-31 16:13:34.3510
# 2              2         71576  2018-01-31 14:23:55.8890
# 3              3         61076  2018-01-31 14:53:23.5620
# 4              4         39966  2018-01-31 19:52:24.6670
# 5              5          6477  2018-01-31 22:58:44.8670
# 6              6           453  2018-01-31 23:53:53.6320
# 7              7           180  2018-01-31 23:52:09.9030
# 8              8           996  2018-01-31 23:34:56.0040
# 9              9           825  2018-01-31 23:34:14.0270
# 10            10          1316  2018-01-31 23:24:00.4160
# 11            11           432  2018-01-31 23:34:26.4840
# 12            12           601  2018-01-31 23:29:46.8320
# 13            13           887  2018-01-31 23:24:16.3570
# 14            14           210  2018-01-31 23:33:03.0460
# 15            15           188  2018-01-31 23:30:58.1360
# 16            16           808  2018-01-31 23:19:58.6030
# 17            17           378  2018-01-31 23:23:23.0680
# 18            18           350  2018-01-31 23:13:45.5290
# 19            19           686  2018-01-31 23:07:15.3130
# 20            20           450  2018-01-31 23:07:13.0630
# 21            21           294  2018-01-31 23:08:12.0000
# 22            22           150  2018-01-31 23:10:09.5860
# 23            23           462  2018-01-31 23:03:48.9400
# 24            24           379  2018-01-31 23:04:27.7010
# 25            25           880  2018-01-31 22:53:41.3020
# 26            26          1210  2018-01-31 22:45:37.1250
# 27            27           259  2018-01-31 23:01:12.7920
# 28            28           592  2018-01-31 22:53:27.7790
# 29            29          1059  2018-01-31 22:45:16.5700
# ...          ...           ...                       ...
# 1863691  1863691           310  2018-12-01 00:45:44.8680
# 1863692  1863692          1338  2018-12-01 00:27:24.8750
# 1863693  1863693           154  2018-12-01 00:44:24.8380
# 1863694  1863694           862  2018-12-01 00:32:11.0630
# 1863695  1863695          1310  2018-12-01 00:23:53.3420
# 1863696  1863696           230  2018-12-01 00:41:31.9550
# 1863697  1863697          2071  2018-12-01 00:09:55.5800
# 1863698  1863698          1958  2018-12-01 00:11:35.0220
# 1863699  1863699           268  2018-12-01 00:37:23.1340
# 1863700  1863700          1679  2018-12-01 00:13:35.1430
# 1863701  1863701          1658  2018-12-01 00:13:33.1240
# 1863702  1863702           293  2018-12-01 00:36:01.5250
# 1863703  1863703           426  2018-12-01 00:32:13.1250
# 1863704  1863704           447  2018-12-01 00:31:36.1480
# 1863705  1863705          1694  2018-12-01 00:09:17.1590
# 1863706  1863706           269  2018-12-01 00:31:00.0910
# 1863707  1863707           685  2018-12-01 00:21:16.2400
# 1863708  1863708           681  2018-12-01 00:19:41.3830
# 1863709  1863709          1166  2018-12-01 00:11:04.8640
# 1863710  1863710           763  2018-12-01 00:17:34.4970
# 1863711  1863711           760  2018-12-01 00:17:29.9600
# 1863712  1863712           538  2018-12-01 00:16:34.0850
# 1863713  1863713           671  2018-12-01 00:12:49.6400
# 1863714  1863714           498  2018-12-01 00:14:41.7250
# 1863715  1863715          1137  2018-12-01 00:01:49.6930
# 1863716  1863716           473  2018-12-01 00:11:54.8110
# 1863717  1863717           841  2018-12-01 00:02:48.7260
# 1863718  1863718           260  2018-12-01 00:05:27.6150
# 1863719  1863719           292  2018-12-01 00:03:06.5490
# 1863720  1863720           150  2018-12-01 00:03:05.7420
#
#                          end_time  start_station_id  \
# 0        2018-02-01 19:47:19.8240             120.0
# 1        2018-02-01 15:57:17.3100              15.0
# 2        2018-02-01 10:16:52.1160             304.0
# 3        2018-02-01 07:51:20.5000              75.0
# 4        2018-02-01 06:58:31.0530              74.0
# 5        2018-02-01 00:46:41.9080             236.0
# 6        2018-02-01 00:01:26.8050             110.0
# 7        2018-01-31 23:55:10.8070              81.0
# 8        2018-01-31 23:51:32.6740             134.0
# 9        2018-01-31 23:47:59.8090             305.0
# 10       2018-01-31 23:45:56.8240              98.0
# 11       2018-01-31 23:41:39.2970              89.0
# 12       2018-01-31 23:39:48.0000             223.0
# 13       2018-01-31 23:39:04.1230             308.0
# 14       2018-01-31 23:36:33.7040               7.0
# 15       2018-01-31 23:34:06.3910              98.0
# 16       2018-01-31 23:33:27.5310              67.0
# 17       2018-01-31 23:29:42.0440              80.0
# 18       2018-01-31 23:19:36.2650             247.0
# 19       2018-01-31 23:18:41.5580             312.0
# 20       2018-01-31 23:14:43.8140             241.0
# 21       2018-01-31 23:13:06.6360             239.0
# 22       2018-01-31 23:12:40.3330             182.0
# 23       2018-01-31 23:11:31.0290             119.0
# 24       2018-01-31 23:10:46.9760             176.0
# 25       2018-01-31 23:08:21.4430             123.0
# 26       2018-01-31 23:05:47.5760             285.0
# 27       2018-01-31 23:05:32.1570             239.0
# 28       2018-01-31 23:03:20.2900             202.0
# 29       2018-01-31 23:02:56.2850             141.0
# ...                           ...               ...
# 1863691  2018-12-01 00:50:55.7970             252.0
# 1863692  2018-12-01 00:49:43.3490             371.0
# 1863693  2018-12-01 00:46:59.3350              70.0
# 1863694  2018-12-01 00:46:33.7900               4.0
# 1863695  2018-12-01 00:45:43.5880              85.0
# 1863696  2018-12-01 00:45:22.4160             312.0
# 1863697  2018-12-01 00:44:26.6290              36.0
# 1863698  2018-12-01 00:44:13.6320              44.0
# 1863699  2018-12-01 00:41:51.9670             147.0
# 1863700  2018-12-01 00:41:34.8600             240.0
# 1863701  2018-12-01 00:41:11.7630             240.0
# 1863702  2018-12-01 00:40:55.2850              95.0
# 1863703  2018-12-01 00:39:19.8710              50.0
# 1863704  2018-12-01 00:39:03.3910             368.0
# 1863705  2018-12-01 00:37:31.2400              14.0
# 1863706  2018-12-01 00:35:29.8710              98.0
# 1863707  2018-12-01 00:32:42.0000             109.0
# 1863708  2018-12-01 00:31:02.6050              15.0
# 1863709  2018-12-01 00:30:31.3480             160.0
# 1863710  2018-12-01 00:30:18.1070              73.0
# 1863711  2018-12-01 00:30:10.1780              73.0
# 1863712  2018-12-01 00:25:32.4550               5.0
# 1863713  2018-12-01 00:24:01.5120              34.0
# 1863714  2018-12-01 00:23:00.4080               7.0
# 1863715  2018-12-01 00:20:47.5190              73.0
# 1863716  2018-12-01 00:19:48.5470             345.0
# 1863717  2018-12-01 00:16:49.7660              10.0
# 1863718  2018-12-01 00:09:47.9560             245.0
# 1863719  2018-12-01 00:07:59.0800              93.0
# 1863720  2018-12-01 00:05:36.0260             107.0
#
#                                         start_station_name  \
# 0                                     Mission Dolores Park
# 1        San Francisco Ferry Building (Harry Bridges Pl...
# 2                                     Jackson St at 5th St
# 3                                 Market St at Franklin St
# 4                                    Laguna St at Hayes St
# 5                                      Market St at 8th St
# 6         17th & Folsom Street Park (17th St at Folsom St)
# 7                                       Berry St at 4th St
# 8                                   Valencia St at 24th St
# 9                                              Ryland Park
# 10                                  Valencia St at 16th St
# 11                              Division St at Potrero Ave
# 12                          16th St Mission BART Station 2
# 13                                        San Pedro Square
# 14                                     Frank H Ogawa Plaza
# 15                                  Valencia St at 16th St
# 16       San Francisco Caltrain Station 2  (Townsend St...
# 17                                   Townsend St at 5th St
# 18                               Fulton St at Bancroft Way
# 19                                San Jose Diridon Station
# 20                                      Ashby BART Station
# 21                           Bancroft Way at Telegraph Ave
# 22                                19th Street BART Station
# 23                                       18th St at Noe St
# 24                                  MacArthur BART Station
# 25                                    Folsom St at 19th St
# 26                              Webster St at O'Farrell St
# 27                           Bancroft Way at Telegraph Ave
# 28                                 Washington St at 8th St
# 29                          Valencia St at Cesar Chavez St
# ...                                                    ...
# 1863691                       Channing Way at Shattuck Ave
# 1863692                         Lombard St at Columbus Ave
# 1863693                             Central Ave at Fell St
# 1863694                        Cyril Magnin St at Ellis St
# 1863695                            Church St at Duboce Ave
# 1863696                           San Jose Diridon Station
# 1863697                                Folsom St at 3rd St
# 1863698  Civic Center/UN Plaza BART Station (Market St ...
# 1863699                             29th St at Tiffany Ave
# 1863700                          Haste St at Telegraph Ave
# 1863701                          Haste St at Telegraph Ave
# 1863702                              Sanchez St at 15th St
# 1863703                              2nd St at Townsend St
# 1863704                               Myrtle St at Polk St
# 1863705                              Clay St at Battery St
# 1863706                             Valencia St at 16th St
# 1863707                             17th St at Valencia St
# 1863708  San Francisco Ferry Building (Harry Bridges Pl...
# 1863709                          West Oakland BART Station
# 1863710                             Pierce St at Haight St
# 1863711                             Pierce St at Haight St
# 1863712       Powell St BART Station (Market St at 5th St)
# 1863713                     Father Alfred E Boeddeker Park
# 1863714                                Frank H Ogawa Plaza
# 1863715                             Pierce St at Haight St
# 1863716                              Hubbell St at 16th St
# 1863717                         Washington St at Kearny St
# 1863718                             Downtown Berkeley BART
# 1863719                       4th St at Mission Bay Blvd S
# 1863720                              17th St at Dolores St
#
#          start_station_latitude  start_station_longitude  end_station_id  \
# 0                     37.761420              -122.426435           285.0
# 1                     37.795392              -122.394203            15.0
# 2                     37.348759              -121.894798           296.0
# 3                     37.773793              -122.421239            47.0
# 4                     37.776435              -122.426244            19.0
# 5                     37.803686              -122.282497           160.0
# 6                     37.763708              -122.415204           134.0
# 7                     37.775880              -122.393170            93.0
# 8                     37.752428              -122.420628             4.0
# 9                     37.342725              -121.895617           317.0
# 10                    37.765052              -122.421866             4.0
# 11                    37.769218              -122.407646            43.0
# 12                    37.764765              -122.420091            86.0
# 13                    37.336802              -121.894090           297.0
# 14                    37.804562              -122.271738           186.0
# 15                    37.765052              -122.421866            76.0
# 16                    37.776639              -122.395526            98.0
# 17                    37.775306              -122.397380            78.0
# 18                    37.867789              -122.265896           274.0
# 19                    37.329732              -121.901782           317.0
# 20                    37.852477              -122.270213           157.0
# 21                    37.868813              -122.258764           244.0
# 22                    37.809013              -122.268247           183.0
# 23                    37.761047              -122.432642           134.0
# 24                    37.828410              -122.266315           189.0
# 25                    37.760594              -122.414817           145.0
# 26                    37.783521              -122.431158           133.0
# 27                    37.868813              -122.258764           266.0
# 28                    37.800754              -122.274894           195.0
# 29                    37.747998              -122.420219            79.0
# ...                         ...                      ...             ...
# 1863691               37.865847              -122.267443           238.0
# 1863692               37.802746              -122.413579           104.0
# 1863693               37.773311              -122.444293            52.0
# 1863694               37.785881              -122.408915            86.0
# 1863695               37.770083              -122.429156            13.0
# 1863696               37.329732              -121.901782           314.0
# 1863697               37.783830              -122.398870            97.0
# 1863698               37.781074              -122.411738             5.0
# 1863699               37.744067              -122.421472           121.0
# 1863700               37.866043              -122.258804           245.0
# 1863701               37.866043              -122.258804           245.0
# 1863702               37.766219              -122.431060            72.0
# 1863703               37.780526              -122.390288            21.0
# 1863704               37.785434              -122.419622            17.0
# 1863705               37.795001              -122.399970           147.0
# 1863706               37.765052              -122.421866           121.0
# 1863707               37.763316              -122.421904            60.0
# 1863708               37.795392              -122.394203           323.0
# 1863709               37.805318              -122.294837           155.0
# 1863710               37.771793              -122.433708           121.0
# 1863711               37.771793              -122.433708           121.0
# 1863712               37.783899              -122.408445            39.0
# 1863713               37.783988              -122.412408            92.0
# 1863714               37.804562              -122.271738           214.0
# 1863715               37.771793              -122.433708            50.0
# 1863716               37.766474              -122.398295            81.0
# 1863717               37.795393              -122.404770            58.0
# 1863718               37.870139              -122.268422           255.0
# 1863719               37.770407              -122.391198           126.0
# 1863720               37.763015              -122.426497           119.0
#
#                                           end_station_name  \
# 0                               Webster St at O'Farrell St
# 1        San Francisco Ferry Building (Harry Bridges Pl...
# 2                                    5th St at Virginia St
# 3                                    4th St at Harrison St
# 4                                     Post St at Kearny St
# 5                                West Oakland BART Station
# 6                                   Valencia St at 24th St
# 7                             4th St at Mission Bay Blvd S
# 8                              Cyril Magnin St at Ellis St
# 9                                San Salvador St at 9th St
# 10                             Cyril Magnin St at Ellis St
# 11       San Francisco Public Library (Grove St at Hyde...
# 12                                 Market St at Dolores St
# 13                                   Locust St at Grant St
# 14                                  Lakeside Dr at 14th St
# 15                              McCoppin St at Valencia St
# 16                                  Valencia St at 16th St
# 17                                     Folsom St at 9th St
# 18                                 Oregon St at Adeline St
# 19                               San Salvador St at 9th St
# 20                                    65th St at Hollis St
# 21                              Shattuck Ave at Hearst Ave
# 22                                Telegraph Ave at 19th St
# 23                                  Valencia St at 24th St
# 24                                     Genoa St at 55th St
# 25                                    29th St at Church St
# 26                                  Valencia St at 22nd St
# 27                                  Parker St at Fulton St
# 28                                     Bay Pl at Vernon St
# 29                                    7th St at Brannan St
# ...                                                    ...
# 1863691                       MLK Jr Way at University Ave
# 1863692                                  4th St at 16th St
# 1863693                          McAllister St at Baker St
# 1863694                            Market St at Dolores St
# 1863695                     Commercial St at Montgomery St
# 1863696                     Santa Clara St at Almaden Blvd
# 1863697                              14th St at Mission St
# 1863698       Powell St BART Station (Market St at 5th St)
# 1863699                                 Mission Playground
# 1863700                             Downtown Berkeley BART
# 1863701                             Downtown Berkeley BART
# 1863702                                Page St at Scott St
# 1863703   Montgomery St BART Station (Market St at 2nd St)
# 1863704   Embarcadero BART Station (Beale St at Market St)
# 1863705                             29th St at Tiffany Ave
# 1863706                                 Mission Playground
# 1863707                               8th St at Ringold St
# 1863708                                 Broadway at Kearny
# 1863709                           Emeryville Public Market
# 1863710                                 Mission Playground
# 1863711                                 Mission Playground
# 1863712                        Scott St at Golden Gate Ave
# 1863713                              Mission Bay Kids Park
# 1863714                         Market St at Brockhurst St
# 1863715                              2nd St at Townsend St
# 1863716                                 Berry St at 4th St
# 1863717                               Market St at 10th St
# 1863718                        Virginia St at Shattuck Ave
# 1863719                                        Esprit Park
# 1863720                                  18th St at Noe St
#
#          end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                   37.783521            -122.431158     2765  Subscriber
# 1                   37.795392            -122.394203     2815    Customer
# 2                   37.325998            -121.877120     3039    Customer
# 3                   37.780955            -122.399749      321    Customer
# 4                   37.788975            -122.403452      617  Subscriber
# 5                   37.805318            -122.294837     1306    Customer
# 6                   37.752428            -122.420628     3571  Subscriber
# 7                   37.770407            -122.391198     1403  Subscriber
# 8                   37.785881            -122.408915     3675  Subscriber
# 9                   37.333955            -121.877349     1453  Subscriber
# 10                  37.785881            -122.408915     1278    Customer
# 11                  37.778768            -122.415929     2928  Subscriber
# 12                  37.769305            -122.426826     3016  Subscriber
# 13                  37.322980            -121.887931       55  Subscriber
# 14                  37.801319            -122.262642     2602  Subscriber
# 15                  37.771662            -122.422423     2556  Subscriber
# 16                  37.765052            -122.421866     3041  Subscriber
# 17                  37.773717            -122.411647      546  Subscriber
# 18                  37.857567            -122.267558      431  Subscriber
# 19                  37.333955            -121.877349     1886  Subscriber
# 20                  37.846784            -122.291376     3583  Subscriber
# 21                  37.873792            -122.268618     2144  Subscriber
# 22                  37.808702            -122.269927     3468  Subscriber
# 23                  37.752428            -122.420628     1432  Subscriber
# 24                  37.839649            -122.271756      997  Subscriber
# 25                  37.743684            -122.426806     3725  Subscriber
# 26                  37.755213            -122.420975     1059  Subscriber
# 27                  37.862464            -122.264791     1208  Subscriber
# 28                  37.812314            -122.260779     1834    Customer
# 29                  37.773492            -122.403673     1248  Subscriber
# ...                       ...                    ...      ...         ...
# 1863691             37.871719            -122.273068      367  Subscriber
# 1863692             37.767045            -122.390833     1985  Subscriber
# 1863693             37.777416            -122.441838      449  Subscriber
# 1863694             37.769305            -122.426826     4408    Customer
# 1863695             37.794231            -122.402923     1525  Subscriber
# 1863696             37.333988            -121.894902     1379  Subscriber
# 1863697             37.768265            -122.420110      316    Customer
# 1863698             37.783899            -122.408445     4395  Subscriber
# 1863699             37.759210            -122.421339     4451  Subscriber
# 1863700             37.870139            -122.268422     3701    Customer
# 1863701             37.870139            -122.268422     3625    Customer
# 1863702             37.772406            -122.435650     1043  Subscriber
# 1863703             37.789625            -122.400811     3154  Subscriber
# 1863704             37.792251            -122.397086     1677  Subscriber
# 1863705             37.744067            -122.421472      209  Subscriber
# 1863706             37.759210            -122.421339     3147  Subscriber
# 1863707             37.774520            -122.409449     3247  Subscriber
# 1863708             37.798014            -122.405950     3460  Subscriber
# 1863709             37.840521            -122.293528     1579  Subscriber
# 1863710             37.759210            -122.421339       90  Subscriber
# 1863711             37.759210            -122.421339     2758  Subscriber
# 1863712             37.778999            -122.436861     4384  Subscriber
# 1863713             37.772301            -122.393028     4377  Subscriber
# 1863714             37.823321            -122.275732     2236  Subscriber
# 1863715             37.780526            -122.390288      273  Subscriber
# 1863716             37.775880            -122.393170     3035  Subscriber
# 1863717             37.776619            -122.417385     2034  Subscriber
# 1863718             37.876573            -122.269528     2243  Subscriber
# 1863719             37.761634            -122.390648      545  Subscriber
# 1863720             37.761047            -122.432642     4319  Subscriber
#
#          member_birth_year member_gender bike_share_for_all_trip
# 0                   1986.0          Male                      No
# 1                      NaN           NaN                      No
# 2                   1996.0          Male                      No
# 3                      NaN           NaN                      No
# 4                   1991.0          Male                      No
# 5                      NaN           NaN                      No
# 6                   1988.0          Male                      No
# 7                   1980.0          Male                      No
# 8                   1987.0          Male                     Yes
# 9                   1994.0        Female                     Yes
# 10                     NaN           NaN                      No
# 11                  1993.0          Male                      No
# 12                  1957.0          Male                      No
# 13                  1976.0        Female                     Yes
# 14                  1976.0          Male                      No
# 15                  1964.0        Female                      No
# 16                  1976.0          Male                     Yes
# 17                  1995.0        Female                      No
# 18                     NaN           NaN                      No
# 19                  1997.0        Female                      No
# 20                  1994.0          Male                      No
# 21                  1983.0          Male                      No
# 22                  1945.0          Male                     Yes
# 23                  1971.0          Male                     Yes
# 24                  1975.0          Male                      No
# 25                  1986.0          Male                      No
# 26                  1991.0          Male                      No
# 27                  1994.0          Male                      No
# 28                  1978.0          Male                      No
# 29                  1988.0          Male                      No
# ...                    ...           ...                     ...
# 1863691             1991.0          Male                      No
# 1863692             1986.0          Male                      No
# 1863693             1994.0          Male                      No
# 1863694             1975.0          Male                      No
# 1863695             1994.0          Male                     Yes
# 1863696             1957.0          Male                      No
# 1863697             1991.0          Male                      No
# 1863698             1993.0          Male                      No
# 1863699             1989.0          Male                      No
# 1863700             1998.0        Female                      No
# 1863701             1998.0        Female                      No
# 1863702             1981.0          Male                      No
# 1863703             1986.0          Male                      No
# 1863704             1980.0         Other                     Yes
# 1863705             1993.0          Male                      No
# 1863706             1993.0          Male                      No
# 1863707             1987.0        Female                      No
# 1863708             1959.0          Male                      No
# 1863709             1997.0          Male                      No
# 1863710             1991.0        Female                      No
# 1863711             1991.0          Male                      No
# 1863712             1991.0          Male                      No
# 1863713             1972.0          Male                     Yes
# 1863714             1992.0          Male                      No
# 1863715             1990.0          Male                      No
# 1863716             1982.0        Female                      No
# 1863717             1999.0        Female                      No
# 1863718             1991.0          Male                      No
# 1863719             1963.0          Male                      No
# 1863720                NaN           NaN                      No
#
# [1863721 rows x 17 columns]

# %%
df.shape
# Out:
# (1863721, 16)

# %%
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %%
df.bike_share_for_all_trip.value_counts()
# Out:
# No     1701386
# Yes     162335
# Name: bike_share_for_all_trip, dtype: int64

# %%
# derive the time duration in terms of minute and hour from duration_sec
df['duration_min'] = df['duration_sec'].apply(lambda d: d/60).astype(float)
df['duration_hr'] = df['duration_min'].apply(lambda d: d/60).astype(float)

# %%
# round to 2 decimals 
df['duration_min'] = df['duration_min'].apply(lambda x: round(x, 2))
df['duration_hr'] = df['duration_hr'].apply(lambda x: round(x, 2))
# Out:
#    duration_sec                start_time                  end_time  \
# 0         75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1         85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2         71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3         61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4         39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
#
#    start_station_id                                 start_station_name  \
# 0             120.0                               Mission Dolores Park
# 1              15.0  San Francisco Ferry Building (Harry Bridges Pl...
# 2             304.0                               Jackson St at 5th St
# 3              75.0                           Market St at Franklin St
# 4              74.0                              Laguna St at Hayes St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.761420              -122.426435           285.0
# 1               37.795392              -122.394203            15.0
# 2               37.348759              -121.894798           296.0
# 3               37.773793              -122.421239            47.0
# 4               37.776435              -122.426244            19.0
#
#                                     end_station_name  end_station_latitude  \
# 0                         Webster St at O'Farrell St             37.783521
# 1  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 2                              5th St at Virginia St             37.325998
# 3                              4th St at Harrison St             37.780955
# 4                               Post St at Kearny St             37.788975
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.431158     2765  Subscriber             1986.0
# 1            -122.394203     2815    Customer                NaN
# 2            -121.877120     3039    Customer             1996.0
# 3            -122.399749      321    Customer                NaN
# 4            -122.403452      617  Subscriber             1991.0
#
#   member_gender bike_share_for_all_trip  duration_min  duration_hr
# 0          Male                      No       1254.73        20.91
# 1           NaN                      No       1423.70        23.73
# 2          Male                      No       1192.93        19.88
# 3           NaN                      No       1017.93        16.97
# 4          Male                      No        666.10        11.10

# %%
# derive the age from members' birth year
df['member_age'] = df['member_birth_year'].apply(lambda b:0 if pd.isnull(b) else 2019-b).astype(int)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1         85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2         71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3         61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4         39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
#
#    start_station_id                                 start_station_name  \
# 0             120.0                               Mission Dolores Park
# 1              15.0  San Francisco Ferry Building (Harry Bridges Pl...
# 2             304.0                               Jackson St at 5th St
# 3              75.0                           Market St at Franklin St
# 4              74.0                              Laguna St at Hayes St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.761420              -122.426435           285.0
# 1               37.795392              -122.394203            15.0
# 2               37.348759              -121.894798           296.0
# 3               37.773793              -122.421239            47.0
# 4               37.776435              -122.426244            19.0
#
#                                     end_station_name  end_station_latitude  \
# 0                         Webster St at O'Farrell St             37.783521
# 1  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 2                              5th St at Virginia St             37.325998
# 3                              4th St at Harrison St             37.780955
# 4                               Post St at Kearny St             37.788975
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.431158     2765  Subscriber             1986.0
# 1            -122.394203     2815    Customer                NaN
# 2            -121.877120     3039    Customer             1996.0
# 3            -122.399749      321    Customer                NaN
# 4            -122.403452      617  Subscriber             1991.0
#
#   member_gender bike_share_for_all_trip  duration_min  duration_hr  member_age
# 0          Male                      No       1254.73        20.91          33
# 1           NaN                      No       1423.70        23.73           0
# 2          Male                      No       1192.93        19.88          23
# 3           NaN                      No       1017.93        16.97           0
# 4          Male                      No        666.10        11.10          28

# %%
# make a copy of the data frame for further exploration
dfc = df.copy()

# %%
# convert end_time column to datetime type
dfc['end_time'] = pd.to_datetime(dfc['end_time'])

# %%
# extract month, date, day, and hour from the end_time column utilizing the datetime library
dfc['month'] = dfc['end_time'].apply(lambda time: time.strftime("%B"))
dfc['date'] = dfc['end_time'].apply(lambda time: time.strftime("%d"))
dfc['day'] = dfc['end_time'].apply(lambda time: time.strftime("%A"))
dfc['hour'] = dfc['end_time'].apply(lambda time: time.strftime("%H"))

# %%
# assign a certain day to weekday/weekend
def assign_weektime(day):
    weekdays = ['Monday','Tuesday', 'Wednesday','Thursday','Friday']
    weekend = ['Saturday', 'Sunday']
    if day in weekdays:
        return "Weekday"
    else:
        return "Weekend"

# %%
dfc['timeofweek'] = dfc['day'].apply(lambda day: assign_weektime(day))

# %%
dfc.timeofweek.value_counts()
# Out:
# Weekday    1534326
# Weekend     329395
# Name: timeofweek, dtype: int64

# %%
dfc['hour'] = dfc['hour'].astype(int)

# %%
# assign a specific time period of the day (morning, afternoon, evening)
def assign_dayperiod(hour):
    if (hour >= 4 and hour <= 12):
        return "Morning"
    elif (hour > 12 and hour <= 18):
        return "Afternoon"
    else:
        return "Evening"

# %%
dfc['dayperiod'] = dfc['hour'].apply(lambda hour: assign_dayperiod(hour))

# %%
dfc.sample(5)
# Out:
#          duration_sec                start_time                end_time  \
# 286524           1043  2018-03-08 17:13:06.0670 2018-03-08 17:30:29.632
# 998314           1449  2018-07-04 18:58:58.6020 2018-07-04 19:23:07.651
# 738890            328  2018-06-13 17:10:04.8460 2018-06-13 17:15:33.730
# 1059438           713  2018-08-25 02:37:53.4770 2018-08-25 02:49:46.598
# 1858742           167  2018-12-02 21:09:40.0430 2018-12-02 21:12:27.705
#
#          start_station_id            start_station_name  \
# 286524               37.0           2nd St at Folsom St
# 998314              350.0          8th St at Brannan St
# 738890              337.0         Webster St at 19th St
# 1059438             269.0  Telegraph Ave at Carleton St
# 1858742             368.0          Myrtle St at Polk St
#
#          start_station_latitude  start_station_longitude  end_station_id  \
# 286524                37.785000              -122.395936            55.0
# 998314                37.771431              -122.405787             6.0
# 738890                37.806970              -122.266588             7.0
# 1059438               37.862320              -122.258801           273.0
# 1858742               37.785434              -122.419622            58.0
#
#                       end_station_name  end_station_latitude  ...  \
# 286524          Webster St at Grove St             37.777053  ...
# 998314   The Embarcadero at Sansome St             37.804770  ...
# 738890             Frank H Ogawa Plaza             37.804562  ...
# 1059438         Fulton St at Ashby Ave             37.855574  ...
# 1858742           Market St at 10th St             37.776619  ...
#
#          bike_share_for_all_trip  duration_min duration_hr  member_age  \
# 286524                        No         17.38        0.29          47
# 998314                        No         24.15        0.40          26
# 738890                        No          5.47        0.09          70
# 1059438                       No         11.88        0.20          23
# 1858742                       No          2.78        0.05          37
#
#             month date        day  hour  timeofweek  dayperiod
# 286524      March   08   Thursday    17     Weekday  Afternoon
# 998314       July   04  Wednesday    19     Weekday    Evening
# 738890       June   13  Wednesday    17     Weekday  Afternoon
# 1059438    August   25   Saturday     2     Weekend    Evening
# 1858742  December   02     Sunday    21     Weekend    Evening
#
# [5 rows x 25 columns]

# %%
# assign age group to the users
def assign_agegroup(age):
    if (age >= 0 and age <=10):
        return "Children"
    elif (age > 10 and age <=20):
        return "Teen"
    elif (age > 20 and age <=35):
        return "Young Adult"
    elif (age > 35 and age <=55):
        return "Adult"
    else:
        return "Senior"

# %%
dfc['member_age_group'] = dfc['member_age'].apply(lambda age: assign_agegroup(age))

# %%
dfc.member_age_group.value_counts()
# Out:
# Young Adult    1003679
# Adult           628064
# Children        110718
# Senior          102522
# Teen             18738
# Name: member_age_group, dtype: int64

# %% [markdown]
# ### Average Trip Duration by Age Group

# %%
age_order = ['Children', 'Teen', 'Young Adult', 'Adult', 'Senior']
age_range = [0, 10, 20, 35, 55, 120]

# %%
sb.boxplot(data=dfc, x="member_age_group", y="duration_min", color=base_color, order=age_order)
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
dfc_byAge = dfc.loc[dfc.member_age != 0].reset_index()

# %%
# bin_edges = np.arange(0, dfc['member_age'].max() + 10, 10)
# bin_idxs = pd.cut(dfc['member_age'], bin_edges, right=False, include_lowest=False).astype(int)
bin_idxs = pd.cut(dfc_byAge['member_age'], age_range, labels=age_order)

# %%
dfc_byAge.head()
# Out:
#    index  duration_sec                start_time                end_time  \
# 0      0         75284  2018-01-31 22:52:35.2390 2018-02-01 19:47:19.824
# 1      2         71576  2018-01-31 14:23:55.8890 2018-02-01 10:16:52.116
# 2      4         39966  2018-01-31 19:52:24.6670 2018-02-01 06:58:31.053
# 3      6           453  2018-01-31 23:53:53.6320 2018-02-01 00:01:26.805
# 4      7           180  2018-01-31 23:52:09.9030 2018-01-31 23:55:10.807
#
#    start_station_id                                start_station_name  \
# 0             120.0                              Mission Dolores Park
# 1             304.0                              Jackson St at 5th St
# 2              74.0                             Laguna St at Hayes St
# 3             110.0  17th & Folsom Street Park (17th St at Folsom St)
# 4              81.0                                Berry St at 4th St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.761420              -122.426435           285.0
# 1               37.348759              -121.894798           296.0
# 2               37.776435              -122.426244            19.0
# 3               37.763708              -122.415204           134.0
# 4               37.775880              -122.393170            93.0
#
#                end_station_name  ...  duration_min  duration_hr  member_age  \
# 0    Webster St at O'Farrell St  ...       1254.73        20.91          33
# 1         5th St at Virginia St  ...       1192.93        19.88          23
# 2          Post St at Kearny St  ...        666.10        11.10          28
# 3        Valencia St at 24th St  ...          7.55         0.13          31
# 4  4th St at Mission Bay Blvd S  ...          3.00         0.05          39
#
#       month  date        day hour  timeofweek  dayperiod  member_age_group
# 0  February    01   Thursday   19     Weekday    Evening       Young Adult
# 1  February    01   Thursday   10     Weekday    Morning       Young Adult
# 2  February    01   Thursday    6     Weekday    Morning       Young Adult
# 3  February    01   Thursday    0     Weekday    Evening       Young Adult
# 4   January    31  Wednesday   23     Weekday    Evening             Adult
#
# [5 rows x 27 columns]

# %% [markdown]
# Last but not least, since a lot of the plots will have number of data rows (i.e., count of trips) as the y axis, let's develop a mechanism to display the trip counts in thousands (K) so it looks cleaner.

# %%
def format_ride_count(count):
    if (count == 0):
        return "0"
    elif (len(str(count)) <=3):
        return str(count)
    else:
        return "{:,}".format(int(count/1000)) + "K"

# %%
# test format function 
format_ride_count(3334334)
# Out:
# '3,334K'

# %% [markdown]
# ### Q1: When does people usually like to bike?

# %% [markdown]
# First of all, we'd like to figure out when people like to bike around in different metrics. That'd be useful to build a pattern that would help better distributing the bikes based on demand of different time periods.

# %% [markdown]
# We'll start off by weekday/weekend.

# %%
plt.figure(figsize=[8,8])
timeofweek_counts = dfc.timeofweek.value_counts()
plt.pie(timeofweek_counts, labels=timeofweek_counts.index, startangle=90, autopct=lambda val: val.round(2));
plt.axis('square');

# %% [markdown]
# Apparently, the majority of the bikes ride on the weekday. Do they bike to commute or just for fun? Maybe taking a look at the day period (morning/afternoon/evening) distribution would help us determine.

# %%
plt.figure(figsize = [12, 10])
dayperiod_order = ['Morning', 'Afternoon', 'Evening']
sb.countplot(data=dfc, x="dayperiod", color=base_color, order=dayperiod_order);
y_ticks_props = np.arange(0, dfc.groupby('dayperiod').bike_id.count().max()+1, 100000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.yticks(y_ticks_props, y_ticks_display);
plt.ylabel('Rides');
plt.title('Ride Distribution in Day Periods', pad=20);

# %% [markdown]
# Maybe they do bike for commuting as the majority of rides takes place during morning and afternoon. To confirm, let's dive deep and take a look at the hourly distribution.

# %%
plt.figure(figsize = [12, 10])
hour_order = np.arange(0, 24, 1)
sb.countplot(data=dfc, x="hour", color=base_color, order=hour_order);
y_ticks_props = np.arange(0, dfc.groupby('hour').bike_id.count().max()+1, 50000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.xticks(np.arange(0, 24+1, 3), np.arange(0, 24+1, 3));
plt.yticks(y_ticks_props, y_ticks_display);
plt.ylabel('Rides');
plt.title('Hourly Ride Distribution');

# %% [markdown]
# It might actually be the case. As we can see from the bar chart, the peak traffic is around 7-9 (morning commute) and 16-18 (afternoon commute(). There's a consistent traffic in between the two peaks, and after 7pm traffic starts to go down.

# %% [markdown]
# Now let's examine the data set from the month's perspective. In which month do people bike the most? Let's find out by building a barplot based on month.

# %%
plt.figure(figsize = [10, 10])
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sb.countplot(data=dfc, y="month", color=base_color, order=month_order);
plt.xlabel('Rides');
x_ticks_props = np.arange(0, dfc.month.value_counts().max()+1, 50000);
x_ticks_display = [ format_ride_count(numRide) for numRide in x_ticks_props]
plt.xticks(x_ticks_props, x_ticks_display);
plt.title('Monthly Ride Distribution');

# %% [markdown]
# To better display the month labels, I've set the barplot to be horizontal. Here we could see that apparently people like to bike in summer and fall - especially in the months from May to October. It makes sense because the weather during that those seasons are more ideal for biking.

# %% [markdown]
# Now that we've examined the data from a chronological standpoint, let's switch gears and try to play around with demographic attributes. Nos vamos!

# %% [markdown]
# ### Q2: Who likes to ride a bike the most?

# %% [markdown]
# We would like to start off with some usual univariate analysis. Let's take a look at the age group - do older people prefer to bike than the younger people?

# %%
plt.figure(figsize = [10, 10])
age_order = ['Children', 'Teen', 'Young Adult', 'Adult', 'Senior']
sb.countplot(data=dfc, y="member_age_group", color=base_color, order=age_order);
x_ticks_props_age = np.arange(0, dfc['member_age_group'].value_counts().max()+1, 250000);
x_ticks_display_age = [ format_ride_count(numRide) for numRide in x_ticks_props_age]
plt.xticks(x_ticks_props_age, x_ticks_display_age);
plt.xlabel('rides');
plt.ylabel('age group');
plt.title('Ride Distribution among Age Aroups');
x_ticks_display_age
# Out:
# ['0', '250K', '500K', '750K', '1,000K']

# %% [markdown]
# This categorization might be a bit general. What if we break down the age by range of 10?

# %%
bin_edges = np.arange(0, dfc.member_age.max(), 10)
dfc['age_by_10'] = pd.cut(dfc.member_age, bin_edges, right=False)

# %%
bin_edges.shape
# Out:
# (14,)

# %%
# todo: convert xtick label to "start_age - end_age", e.g., 10-20 instead of [10, 20]
plt.figure(figsize=[15,10])
sb.countplot(data=dfc, y="age_by_10", color=base_color);
x_ticks_props = np.arange(0, dfc['age_by_10'].value_counts().max()+1, 100000);
x_ticks_display = [ format_ride_count(numRide) for numRide in x_ticks_props]
plt.xticks(x_ticks_props, x_ticks_display);
plt.xlabel('rides');
plt.ylabel('age');
plt.title('Ride Distribution among Age Aroups, range of 10');

# %% [markdown]
# As we could see from above, most riders fall into the range of 20-50, which makes sense. Let's now try a bivariate visualization. What's the relationship between trip duration and age group? For the sake of simplicity, we'll use the duration in minute as our metric.

# %%
plt.figure(figsize = [20, 10])
plt.subplot(1, 2, 1)
ax1 = sb.violinplot(data=dfc, x="member_age_group", y="duration_min", color=base_color, order=age_order)
plt.ylim(0, 50);
plt.ylabel("Duration (min)")

plt.subplot(1, 2, 2)
ax2 = sb.boxplot(data=dfc, x="member_age_group", y="duration_min", color=base_color, order=age_order)
plt.ylabel("Duration (min)");
plt.ylim(0, 50);

# %% [markdown]
# As we could see, surprisingly children seem to have the longest duration. However as we recall for a lot the records that don't have a birth year, we simply assign their age to be 0. Let's clean it up and run the plots again.

# %%
dfc.query('member_age == 0').count()['bike_id']
# Out:
# 110718

# %%
dfc_by_age = dfc.loc[dfc.member_age != 0]

# %%
dfc_by_age.member_age_group.value_counts()
# Out:
# Young Adult    1003679
# Adult           628064
# Senior          102522
# Teen             18738
# Name: member_age_group, dtype: int64

# %%
plt.figure(figsize = [20, 10])
plt.subplot(1, 2, 1)
ax1 = sb.violinplot(data=dfc_by_age, x="member_age_group", y="duration_min", color=base_color, order=age_order[1:])
plt.ylim(0, 50);
plt.xlabel("Age Group", fontsize='x-small');
plt.ylabel("Duration (min)")

plt.subplot(1, 2, 2)
ax2 = sb.boxplot(data=dfc_by_age, x="member_age_group", y="duration_min", color=base_color, order=age_order[1:])
plt.xlabel("Age Group", fontsize='x-small');
plt.ylabel("Duration (min)");
plt.ylim(0, 50);

# %% [markdown]
# Hmm, that makes a difference. Now the children group is completely gone - and teens take the lead among all age groups. Surprisingly, the seniors come nextm trailing by a small margin.

# %% [markdown]
# Next, let's examine the distribution between user types (subscriber/customer)

# %%
g = sb.FacetGrid(data=dfc, col="user_type");
sb.set(font_scale = 3)
g.fig.set_size_inches(20,10)
g.map(plt.hist, "duration_min", range=[0,40]);
g.set_titles('{col_name}', pad=20);
for ax in g.axes.flatten():
    ax.set_xlabel('Duration (min)');
y_ticks_props = np.arange(0, dfc.user_type.value_counts().max()+1, 100000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.yticks(y_ticks_props, y_ticks_display);

# %% [markdown]
# As we could see, the majority of users are subscribers while just a small portion of users are occasional customers. For both groups, most data points fall into the range of 0-20 minutes. Nevertheless, the spread of subscribers is much greater than the customers, which is comparatively more even-out. For subscribers, the bulk of the data points of subscribers fall in 5-15 minutes.

# %% [markdown]
# ### Q3: How about taking both time and age into consideration in terms of the trip duration?

# %% [markdown]
# Let's try to draw a clustered bar plot to illustrate the impacts of day period (morning/afternoon/evening) and age on average trip duration.

# %%
plt.figure(figsize = [24, 10])
ax = sb.barplot(data=dfc_by_age, x="member_age_group", y="duration_min", hue="dayperiod", order=age_order, palette="BuGn_r");
ax.legend(loc=3, framealpha=0.8)
plt.title("Relationship between Trip Duration and Daytime, Age", pad=20);
plt.xlabel("Age Group");
plt.ylabel("Trip Duration");

# %% [markdown]
# We could also examine the relationship from a hourly perspective. Here we will draw a line chart of different age group's ride count in 24 hours.

# %%
plt.figure(figsize = [15, 20])
dfc_by_age_sample = dfc_by_age.groupby(['member_age_group', 'hour']).bike_id.count().reset_index()
sb.lineplot(data=dfc_by_age_sample, x="hour", y="bike_id", hue="member_age_group")
y_ticks_props = np.arange(0, dfc_by_age.groupby(['member_age_group', 'hour']).bike_id.count().max()+1, 20000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.yticks(y_ticks_props, y_ticks_display);
plt.ylabel("Rides");
plt.legend(loc=2, fontsize='xx-small')

# %%
#todo: change the y_tick_props so that it's not hard-coded 
g = sb.FacetGrid(data=dfc_by_age, hue="member_age_group", height=12);
g.map(plt.hist, "hour", histtype="step");
plt.legend(fontsize='xx-small', loc=2);
plt.xticks(np.arange(0, 24+1, 3));
plt.ylabel("Number of Rides");
y_ticks_props = np.arange(0, 250000, 50000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.yticks(y_ticks_props, y_ticks_display);

# %% [markdown]
# Wonderful! So through the line plot as well as the pseudo-histogram we can see that almost all the age groups share the same pattern in terms of hourly rides, with two peaks in the morning and late afternoon/early evening. For teens, the pattern is not so obvious but that's also because the sample size is smaller compared to the other groups.

# %% [markdown]
# ### Q4: What factors has the most influence on trip duration?

# %% [markdown]
# First of all, let's take a look at the overall distribution of trip duration (in minutes).

# %%
#todo: change the y_tick_props so that it's not hard-coded 
#todo: figure out set margin b/n ylabel and y-axis
plt.figure(figsize=[15,12])
plt.hist(df.duration_min, range=[0,40])
plt.xticks(np.arange(0, 40+1, 10))
y_ticks_props = np.arange(0, 600000+1, 50000);
y_ticks_display = [ format_ride_count(numRide) for numRide in y_ticks_props]
plt.yticks(y_ticks_props, y_ticks_display);
plt.xlabel("Trip Duration(min)");
plt.ylabel("Trips");
plt.title("Distribution of Trip Duration (min)", pad=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Trip Duration (min)')

# %% [markdown]
# Since there are a number of individual numerical factors (e.g., age, time, etc) that could impact the trip duration, why don't we examine the relationship between everyone of them?

# %%
dfc.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip',
#        'duration_min', 'duration_hr', 'member_age', 'month', 'date', 'day',
#        'hour', 'timeofweek', 'dayperiod', 'member_age_group', 'age_by_10'],
#       dtype='object')

# %% [markdown]
# ### Q4: In which area does people bike the most?
# #### Station name
# #### Longitude, Latitude
# #### City/State derived from lon/lat? (if time permits)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="baywheel_geo")
location = geolocator.geocode("175 5th Avenue NYC")

# %%
lat, lon = dfc.loc[0, ['start_station_latitude', 'start_station_longitude']]

# %%
print("longitude = ", lon)
print("latitude = ", lat)
# Out:
# longitude =  -122.4264353
# latitude =  37.7614205

# %%
start_coordinates = "{0}, {1}".format(lat, lon)

# %%
start_loc = geolocator.reverse(start_coordinates).address

# %%
start_loc
# Out:
# 'Mission High School, 3750, 18th Street, Castro District, SF, California, 94114, USA'

# %%
start_loc_attrs = start_loc.split(',')
start_loc_attrs
# Out:
# ['Mission High School',
#  ' 3750',
#  ' 18th Street',
#  ' Castro District',
#  ' SF',
#  ' California',
#  ' 94114',
#  ' USA']

# %% [markdown]
# ##### start_loc_city = start_loc_attrs[]
